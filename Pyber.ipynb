# %% [markdown]
# # 5.2 Pyber
# [Overview](https://courses.bootcampspot.com/courses/2523/modules/items/806098

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as stats
import os 
import scipy.stats as sts

# %%
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# alternatively...
# os.path.join("Resources", "city_data.csv")
# os.path.join("Resources", "ride_data.csv")

# %%
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
city_data_df
# Out:
#                 city  driver_count   type
# 0        Richardfort            38  Urban
# 1       Williamsstad            59  Urban
# 2        Port Angela            67  Urban
# 3         Rodneyfort            34  Urban
# 4        West Robert            39  Urban
# ..               ...           ...    ...
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural
#
# [120 rows x 3 columns]

# %%
ride_data_df
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %% [markdown]
# ## Clean City Data

# %%
# find nulls values (basically any inconsistencies in count of each column will indicate null values)
city_data_df.count()
# Out:
# city            120
# driver_count    120
# type            120
# dtype: int64

# %%
# find nulls... this literally counts null cells
city_data_df.isnull().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
city_data_df.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
city_data_df["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
sum(city_data_df["type"]=="Urban")
# Out:
# 66

# %%
sum(city_data_df["type"]=="Suburban")
# Out:
# 36

# %%
sum(city_data_df["type"]=="Rural")
# Out:
# 18

# %% [markdown]
# ## Clean Ride Data

# %%
ride_data_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
ride_data_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the DataFrame
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %% [markdown]
# ## 5.3.1
# [Create DataFrames for Each Type of City](https://courses.bootcampspot.com/courses/2523/pages/5-dot-3-1-create-dataframes-for-each-type-of-city?module_item_id=806114)

# %%
urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
urban_cities_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 1620        Reynoldsfurt  2019-02-14 11:25:10  39.40  9070692324754
# 1621     Christopherfurt  2019-03-13 01:47:52  32.05  2788817929605
# 1622        Raymondhaven  2019-03-20 02:20:34  38.53  8658255136559
# 1623       Port Johnbury  2019-03-26 07:22:45   7.63  8089282605778
# 1624        West Gabriel  2019-05-05 01:24:06  27.57  4428773411209
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
suburban_cities_df
# Out:
#                  city                 date   fare        ride_id  \
# 1625    Barronchester  2019-01-27 03:08:01  27.79  6653622887913
# 1626    East Kentstad  2019-04-07 19:44:19  18.75  6575961095852
# 1627        Lake Omar  2019-01-17 21:33:35  21.71   966911700371
# 1628       Myersshire  2019-02-27 17:38:39  17.10  5706770909868
# 1629      West Hannah  2019-04-19 01:06:59  37.78  2273047151891
# ...               ...                  ...    ...            ...
# 2245      West Hannah  2019-03-02 17:06:03  13.92  7388937249208
# 2246  Lake Robertside  2019-04-03 03:27:45  12.76  1301757653884
# 2247      Colemanland  2019-01-10 06:49:58  27.70  8704067171414
# 2248   East Marymouth  2019-02-12 23:18:53  47.41  7409660239158
# 2249      New Raymond  2019-02-11 17:28:27  17.97  7551674475043
#
#       driver_count      type
# 1625            11  Suburban
# 1626            20  Suburban
# 1627            22  Suburban
# 1628            19  Suburban
# 1629            12  Suburban
# ...

# %%
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
rural_cities_df
# Out:
#                  city                 date   fare        ride_id  \
# 2250   Randallchester  2019-04-13 11:13:31  43.22  1076079536213
# 2251      North Holly  2019-02-02 14:54:00  12.42  1985256326182
# 2252      Michaelberg  2019-03-27 18:27:34  54.85  4421836952718
# 2253  Lake Latoyabury  2019-02-23 21:12:24  47.90  3269652929887
# 2254  Lake Latoyabury  2019-05-06 08:57:56  51.80  4018025271936
# ...               ...                  ...    ...            ...
# 2370      Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371  Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372      North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373     West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374       Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 2250             9  Rural
# 2251             8  Rural
# 2252             6  Rural
# 2253             2  Rural
# 2254             2  Rural
# ...

# %%
# 5.3.2 Get the Number of Rides for Each City Type

# %%
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
urban_ride_count.head()
# Out:
# city
# Amandaburgh        18
# Barajasview        22
# Carriemouth        27
# Christopherfurt    27
# Deanville          19
# Name: ride_id, dtype: int64

# %%
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]
suburban_ride_count.head()
# Out:
# city
# Barronchester    16
# Bethanyland      18
# Brandonfort      19
# Colemanland      22
# Davidfurt        17
# Name: ride_id, dtype: int64

# %%
rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]
rural_ride_count.head()
# Out:
# city
# Bradshawfurt      10
# Garzaport          3
# Harringtonfort     6
# Jessicaport        6
# Lake Jamie         6
# Name: ride_id, dtype: int64

# %%
# 5.3.3 Get the Average Fare for Each City Type

# %%
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
urban_avg_fare
# Out:
# city
# Amandaburgh            24.641667
# Barajasview            25.332273
# Carriemouth            28.314444
# Christopherfurt        24.501852
# Deanville              25.842632
#                          ...
# West Patrickchester    28.233125
# West Robert            25.123871
# West Samuelburgh       21.767600
# Williamsstad           24.362174
# Williamsview           26.599000
# Name: fare, Length: 66, dtype: float64

# %%
suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
suburban_avg_fare.head()
# Out:
# city
# Barronchester    36.422500
# Bethanyland      32.956111
# Brandonfort      35.437368
# Colemanland      30.894545
# Davidfurt        31.995882
# Name: fare, dtype: float64

# %%
rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare.head()
# Out:
# city
# Bradshawfurt      40.064000
# Garzaport         24.123333
# Harringtonfort    33.470000
# Jessicaport       36.013333
# Lake Jamie        34.358333
# Name: fare, dtype: float64

# %%
#5.3.4 Get the Average Number of Drivers for Each City Type

# %%
urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
urban_driver_count.head()
# Out:
# city
# Amandaburgh        12.0
# Barajasview        26.0
# Carriemouth        52.0
# Christopherfurt    41.0
# Deanville          49.0
# Name: driver_count, dtype: float64

# %%
suburban_driver_count = suburban_cities_df.groupby(["city"]).mean()["driver_count"]
suburban_driver_count.head()
# Out:
# city
# Barronchester    11.0
# Bethanyland      22.0
# Brandonfort      10.0
# Colemanland      23.0
# Davidfurt        23.0
# Name: driver_count, dtype: float64

# %%
rural_driver_count = rural_cities_df.groupby(["city"]).mean()["driver_count"]
rural_driver_count.head()
# Out:
# city
# Bradshawfurt      7.0
# Garzaport         7.0
# Harringtonfort    4.0
# Jessicaport       1.0
# Lake Jamie        4.0
# Name: driver_count, dtype: float64

# %% [markdown]
# ## 5.3.5
# [Create Bubble Charts](https://courses.bootcampspot.com/courses/2523/pages/5-dot-3-5-create-bubble-charts?module_item_id=806124)

# %%
plt.scatter(
    urban_ride_count, 
    urban_avg_fare,
    s=10*urban_driver_count,c="coral",
    edgecolor="k",linewidths=1,
    alpha=0.8, label="Urban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
plt.scatter(
    suburban_ride_count, 
    suburban_avg_fare,
    s=10*suburban_driver_count,c="skyblue",
    edgecolor="k",linewidths=1,
    alpha=0.8, label="Rural")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
plt.scatter(
    rural_ride_count, 
    rural_avg_fare,
    s=10*rural_driver_count,c="gold",
    edgecolor="k",linewidths=1,
    alpha=0.8, label="Rural")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
# Combine three plots
plt.scatter(
    urban_ride_count, 
    urban_avg_fare,
    s=10*urban_driver_count,c="coral",
    edgecolor="k",linewidths=1,
    alpha=0.8, label="Urban")


plt.scatter(
    suburban_ride_count, 
    suburban_avg_fare,
    s=10*suburban_driver_count,c="skyblue",
    edgecolor="k",linewidths=1,
    alpha=0.8, label="Rural")


plt.scatter(
    rural_ride_count, 
    rural_avg_fare,
    s=10*rural_driver_count,c="gold",
    edgecolor="k",linewidths=1,
    alpha=0.8, label="Rural")

plt.title("PyBer Ride-Sharing Data (2019)",fontsize=20)
plt.ylabel("Average Fare ($)",fontsize=12)
plt.xlabel("Total Number of Rides (Per City)",fontsize=12)
plt.grid(True)

# Create a legend
lgnd = plt.legend(fontsize="12", mode="Expanded",
         scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)

plt.text(42, 35, 
         "Note: Circle size correlates with driver count per city.", 
         fontsize="12")

plt.show()

plt.savefig("analysis/Fig1.png")

# %% [markdown]
# ## 5.4.1
# [Summary Statistics for Number of Rides by City Type](https://courses.bootcampspot.com/courses/2523/pages/5-dot-4-1-summary-statistics-for-number-of-rides-by-city-type?module_item_id=806134)

# %%
# Get summary statistics.
urban_cities_df.describe()
# Out:
#               fare       ride_id  driver_count
# count  1625.000000  1.625000e+03   1625.000000
# mean     24.525772  4.873485e+12     36.678154
# std      11.738649  2.907440e+12     20.075545
# min       4.050000  1.458810e+10      3.000000
# 25%      14.550000  2.400244e+12     22.000000
# 50%      24.640000  4.711188e+12     37.000000
# 75%      34.580000  7.451579e+12     52.000000
# max      44.970000  9.991538e+12     73.000000

# %%
# Get summary statistics.
suburban_cities_df.describe()
# Out:
#              fare       ride_id  driver_count
# count  625.000000  6.250000e+02    625.000000
# mean    30.970128  4.971015e+12     13.712000
# std     10.677508  2.912410e+12      8.042372
# min     12.050000  3.218337e+08      1.000000
# 25%     21.970000  2.364253e+12      5.000000
# 50%     30.750000  5.053221e+12     16.000000
# 75%     39.830000  7.551674e+12     21.000000
# max     49.960000  9.917744e+12     25.000000

# %%
# Get summary statistics.
rural_cities_df.describe()
# Out:
#              fare       ride_id  driver_count
# count  125.000000  1.250000e+02    125.000000
# mean    34.623440  4.647746e+12      4.296000
# std     14.558046  2.887834e+12      2.691156
# min     10.110000  2.684873e+10      1.000000
# 25%     19.900000  2.275364e+12      1.000000
# 50%     37.050000  4.023962e+12      4.000000
# 75%     47.070000  7.118047e+12      7.000000
# max     58.550000  9.990581e+12      9.000000

# %%
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
suburban_ride_count.describe()
# Out:
# count    36.000000
# mean     17.361111
# std       4.323707
# min       9.000000
# 25%      14.000000
# 50%      17.000000
# 75%      19.250000
# max      27.000000
# Name: ride_id, dtype: float64

# %%
rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
# Calculate the mean of the ride count for each city type.
round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
# Calculate the mean of the ride count for each city type.
round(urban_ride_count.median(),2), round(suburban_ride_count.median(),2), round(rural_ride_count.median(),2)
# Out:
# (24.0, 17.0, 6.0)

# %%
round(urban_ride_count.mode(),2), round(suburban_ride_count.mode(),2), round(rural_ride_count.mode(),2)
# Out:
# (0    22
#  1    25
#  dtype: int64,
#  0    17
#  dtype: int64,
#  0    6
#  dtype: int64)

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the ride counts for urban trips is 24.62.
# The median for the ride counts for urban trips is 24.0.
# The mode for the ride counts for urban trips is ModeResult(mode=array([22]), count=array([7])).

# %%
mean_suburban_ride_count = np.mean(suburban_ride_count)
print(f"The mean for the ride counts for suburban trips is {mean_suburban_ride_count:.2f}.")

median_suburban_ride_count = np.median(suburban_ride_count)
print(f"The median for the ride counts for suburban trips is {median_suburban_ride_count}.")

mode_suburban_ride_count = sts.mode(suburban_ride_count)
print(f"The mode for the ride counts for suburban trips is {mode_suburban_ride_count}.")
# Out:
# The mean for the ride counts for suburban trips is 17.36.
# The median for the ride counts for suburban trips is 17.0.
# The mode for the ride counts for suburban trips is ModeResult(mode=array([17]), count=array([7])).

# %%
mean_rural_ride_count = np.mean(rural_ride_count)
print(f"The mean for the ride counts for rural trips is {mean_rural_ride_count:.2f}.")

median_rural_ride_count = np.median(rural_ride_count)
print(f"The median for the ride counts for rural trips is {median_rural_ride_count}.")

mode_rural_ride_count = sts.mode(rural_ride_count)
print(f"The mode for the ride counts for rural trips is {mode_rural_ride_count}.")
# Out:
# The mean for the ride counts for rural trips is 6.94.
# The median for the ride counts for rural trips is 6.0.
# The mode for the ride counts for rural trips is ModeResult(mode=array([6]), count=array([5])).

# %% [markdown]
# ## 5.4.2
# [Summary Statistics for the Fare by City Type](https://courses.bootcampspot.com/courses/2523/pages/5-dot-4-2-summary-statistics-for-the-fare-by-city-type?module_item_id=806137)

# %%
urban_fares = urban_cities_df["fare"]
urban_fares.head()
# Out:
# 0    13.83
# 1    30.24
# 2    33.44
# 3    23.44
# 4    34.58
# Name: fare, dtype: float64

# %%
suburban_fares = suburban_cities_df["fare"]
suburban_fares.head()
# Out:
# 1625    27.79
# 1626    18.75
# 1627    21.71
# 1628    17.10
# 1629    37.78
# Name: fare, dtype: float64

# %%
rural_fares = rural_cities_df["fare"]
rural_fares.head()
# Out:
# 2250    43.22
# 2251    12.42
# 2252    54.85
# 2253    47.90
# 2254    51.80
# Name: fare, dtype: float64

# %%
mean_urban_fares = np.mean(urban_fares)
print(f"The mean for the fares of urban trips is {mean_urban_fares:.2f}.")

median_urban_fares = np.median(urban_fares)
print(f"The median for the fares of urban trips is {median_urban_fares}.")

mode_urban_fares = sts.mode(urban_fares)
print(f"The mode for the fares of urban trips is {mode_urban_fares}.")
# Out:
# The mean for the fares of urban trips is 24.53.
# The median for the fares of urban trips is 24.64.
# The mode for the fares of urban trips is ModeResult(mode=array([22.86]), count=array([5])).

# %%
mean_suburban_fares = np.mean(suburban_fares)
print(f"The mean for the fares of suburban trips is {mean_suburban_fares:.2f}.")

median_suburban_fares = np.median(suburban_fares)
print(f"The median for the fares of suburban trips is {median_suburban_fares}.")

mode_suburban_fares = sts.mode(suburban_fares)
print(f"The mode for the fares of suburban trips is {mode_suburban_fares}.")
# Out:
# The mean for the fares of suburban trips is 30.97.
# The median for the fares of suburban trips is 30.75.
# The mode for the fares of suburban trips is ModeResult(mode=array([17.99]), count=array([3])).

# %%
mean_rural_fares = np.mean(rural_fares)
print(f"The mean for the fares of rural trips is {mean_rural_fares:.2f}.")

median_rural_fares = np.median(rural_fares)
print(f"The median for the fares of rural trips trips is {median_rural_fares}.")

mode_rural_fares = sts.mode(rural_fares)
print(f"The mode for the fares of rural trips is {mode_rural_fares}.")
# Out:
# The mean for the fares of rural trips is 34.62.
# The median for the fares of rural trips trips is 37.05.
# The mode for the fares of rural trips is ModeResult(mode=array([37.05]), count=array([2])).

# %% [markdown]
# ## 5.4.3
# [Summary Statistics for the Number of Drivers by City Type](https://courses.bootcampspot.com/courses/2523/pages/5-dot-4-3-summary-statistics-for-the-number-of-drivers-by-city-type?module_item_id=806141)

# %%
urban_drivers = urban_cities_df["driver_count"]
urban_drivers.head()
# Out:
# 0     5
# 1    72
# 2    57
# 3    34
# 4    46
# Name: driver_count, dtype: int64

# %%
suburban_drivers = suburban_cities_df["driver_count"]
suburban_drivers.head()
# Out:
# 1625    11
# 1626    20
# 1627    22
# 1628    19
# 1629    12
# Name: driver_count, dtype: int64

# %%
rural_drivers = rural_cities_df["driver_count"]
rural_drivers.head()
# Out:
# 2250    9
# 2251    8
# 2252    6
# 2253    2
# 2254    2
# Name: driver_count, dtype: int64

# %%
mean_urban_drivers = np.mean(urban_drivers)
print(f"The mean for the driver counts for urban cities is {mean_urban_drivers:.2f}.")

median_urban_drivers = np.median(urban_drivers)
print(f"The median for the driver counts for urban citiesis {median_urban_drivers}.")

mode_urban_drivers = sts.mode(urban_drivers)
print(f"The mode for the driver counts for urban cities is {mode_urban_drivers}.")
# Out:
# The mean for the driver counts for urban cities is 36.68.
# The median for the driver counts for urban citiesis 37.0.
# The mode for the driver counts for urban cities is ModeResult(mode=array([39]), count=array([86])).

# %%
mean_suburban_drivers = np.mean(suburban_drivers)
print(f"The mean for the driver counts for suburban cities is {mean_suburban_drivers:.2f}.")

median_suburban_drivers = np.median(suburban_drivers)
print(f"The median for the driver counts for suburban cities is {median_suburban_drivers}.")

mode_suburban_drivers = sts.mode(suburban_drivers)
print(f"The mode for the driver counts for suburban cities is {mode_suburban_drivers}.")
# Out:
# The mean for the driver counts for suburban cities is 13.71.
# The median for the driver counts for suburban cities is 16.0.
# The mode for the driver counts for suburban cities is ModeResult(mode=array([20]), count=array([79])).

# %%
mean_rural_drivers = np.mean(rural_drivers)
print(f"The mean for the driver counts for rural cities is {mean_rural_drivers:.2f}.")

median_rural_drivers = np.median(rural_drivers)
print(f"The median for the driver counts for rural cities is {median_rural_drivers}.")

mode_rural_drivers = sts.mode(rural_drivers)
print(f"The mode for the driver counts for rural cities is {mode_rural_drivers}.")
# Out:
# The mean for the driver counts for rural cities is 4.30.
# The median for the driver counts for rural cities is 4.0.
# The mode for the driver counts for rural cities is ModeResult(mode=array([1]), count=array([32])).

# %% [markdown]
# ## 5.4.4
# [Create Box-and-Whisker Plots](https://courses.bootcampspot.com/courses/2523/pages/5-dot-4-4-create-box-and-whisker-plots?module_item_id=806144)

# %%
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_ride_count, labels=x_labels)

ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(10, 41, step=2.0))
ax.grid(True)
plt.show()

# %%
x_labels = ["Subrban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_ride_count, labels=x_labels)

ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(10, 40, step=2.0))
ax.grid(True)
plt.show()

# %%
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(suburban_ride_count, labels=x_labels)

ax.set_title("Ride Count Data (2019)")
ax.set_ylabel("Number of Rides")
ax.set_yticks(np.arange(10,40,step=2.0))
ax.grid(True)
plt.show()

# %%
# Add all ride count box-and-whisker plots to the same graph.
x_labels = ["Urban", "Suburban","Rural"]
ride_count_data = [urban_ride_count, suburban_ride_count, rural_ride_count]
fig, ax = plt.subplots(figsize=(10, 6))

ax.set_title('Ride Count Data (2019)',fontsize=20)
ax.set_ylabel('Number of Rides',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 45, step=3.0))
ax.grid()

# Save the figure.
plt.savefig("analysis/Fig2.png")
plt.show()

# %%
# Get the city that matches 39.
urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]
print(f"{urban_city_outlier} has the highest rider count.")
# Out:
# West Angela has the highest rider count.

# %%
# Create a box-and-whisker plot for the urban fare data.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_fares, labels=x_labels)

# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()

# Display details as well
print("Summary Statistics")
urban_fares.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       24.525772
# std        11.738649
# min         4.050000
# 25%        14.550000
# 50%        24.640000
# 75%        34.580000
# max        44.970000
# Name: fare, dtype: float64

# %%
# Create a box-and-whisker plot for the suburban fare data.
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_fares, labels=x_labels)

# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()

# Display details as well
print("Summary Statistics")
suburban_fares.describe()
# Out:
# Summary Statistics
# count    625.000000
# mean      30.970128
# std       10.677508
# min       12.050000
# 25%       21.970000
# 50%       30.750000
# 75%       39.830000
# max       49.960000
# Name: fare, dtype: float64

# %%
# Create a box-and-whisker plot for the rural fare data.
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_fares, labels=x_labels)

# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()

# Display details as well
print("Summary Statistics")
rural_fares.describe()
# Out:
# Summary Statistics
# count    125.000000
# mean      34.623440
# std       14.558046
# min       10.110000
# 25%       19.900000
# 50%       37.050000
# 75%       47.070000
# max       58.550000
# Name: fare, dtype: float64

# %%
x_labels = ["Urban", "Suburban", "Rural"]
ride_fare_data= [urban_fares, suburban_fares, rural_fares]
fig, ax = plt.subplots(figsize=(10,6))

ax.boxplot(ride_fare_data, labels=x_labels)
ax.set_title('Ride Fare Data (2019)', fontweight='bold')
ax.set_ylabel('Fare($USD)')
ax.set_xlabel("City Types")
ax.set_yticks(np.arange(0, 60, step=5.0))
ax.grid()

plt.savefig("analysis/Fig3.png")
plt.show()

# %%
# Create the box-and-whisker plot for the urban driver count data.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_drivers,labels=x_labels)

# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()

print("Summary Statistics")
urban_drivers.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       36.678154
# std        20.075545
# min         3.000000
# 25%        22.000000
# 50%        37.000000
# 75%        52.000000
# max        73.000000
# Name: driver_count, dtype: float64

# %%
# Create the box-and-whisker plot for the suburban driver count data.
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_drivers,labels=x_labels)

# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()

print("Summary Statistics")
suburban_drivers.describe()
# Out:
# Summary Statistics
# count    625.000000
# mean      13.712000
# std        8.042372
# min        1.000000
# 25%        5.000000
# 50%       16.000000
# 75%       21.000000
# max       25.000000
# Name: driver_count, dtype: float64

# %%
# Create the box-and-whisker plot for the rural driver count data.
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_drivers,labels=x_labels)

# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()

print("Summary Statistics")
rural_drivers.describe()
# Out:
# Summary Statistics
# count    125.000000
# mean       4.296000
# std        2.691156
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        7.000000
# max        9.000000
# Name: driver_count, dtype: float64

# %%
x_labels = ["Rural", "Suburban", "Rural"]
driver_data = [urban_drivers, suburban_drivers, rural_drivers]
fig, ax = plt.subplots()

ax.boxplot(driver_data, labels=x_labels)
ax.set_title('Driver Count Data (2019)',fontweight='bold')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 80, step=5.0))
ax.grid()
plt.show() 

plt.savefig("analysis/Fig4.png")
plt.show()
# Out:
# Summary Statistics
# count    125.000000
# mean       4.296000
# std        2.691156
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        7.000000
# max        9.000000
# Name: driver_count, dtype: float64
